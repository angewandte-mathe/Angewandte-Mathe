# %% [markdown]
# # Aufgabe 2 a)

# %% [markdown]
# # Wie ich denke, dass es richtig sein sollte, ist aber nicht..

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint


#Anfangsbedienungen

# Vektor - Anfangsort

C = [4,3]

# Anfangsbedienung - Geschwindigkeit  x = 0, y = 1
z0 = [0, 1]   


t = np.linspace(0,10)
g = 9.81

C1 = C[0]
C2 = C[1]

def model1(z,t):
    x = z[0]
    y = z[1]
    dxdtFirst = C1 * t + x
    dydtFirst = -1/2 * F * t**2 + C2 * t + y
    return[dxdtFirst,dydtFirst]

def model2(z,t):    
    dxdtSecond = C1 
    dydtSecond = -g*t + C2  
    return[dxdtSecond,dydtSecond]

def model3(z,t):
    dxdtThird = 0
    dydtThird = -g
    return[dxdtThird,dydtThird]

z1 = odeint( func=model1, y0=z0, t=t )
z2 = odeint( func=model2, y0=z0, t=t )
z3 = odeint( func=model3, y0=z0, t=t )

x1=z1[:,0]
y1=z1[:,1]
x2=z2[:,0]
y2=z2[:,1]
x3=z3[:,0]
y3=z3[:,1]


#plt.plot(z1[0], z1[1], z2[0], z2[1], z3[0], z3[1])
#plt.plot(z2[0], z2[1])
#plt.plot(z3[0], z3[1])

#plt.plot(x1,y1)
#plt.plot(x2,y2)
#plt.plot(x3,y3)

plt.plot(t,z1)
plt.plot(t,z2)
plt.plot(t,z3)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint


#Anfangsbedienungen

# Vektor - Anfangsort

C = [1,3]

# Anfangsbedienung - Geschwindigkeit  x = 0, y = 1
z0 = [0, 1, 0,1 ,0,1]   


t = np.linspace(0,10)
g = 9.81

C1 = C[0]
C2 = C[1]

def model1(z,t):
    x = z[0]
    y = z[1]
    
    
    dxdtFirst = C1 * t + x
    dydtFirst = -1/2 * F * t**2 + C2 * t + y
    dxdtSecond = C1 
    dydtSecond = -g*t + C2  
    dxdtThird = 0
    dydtThird = -g
    
    z0 = [0, 6, dxdtSecond, dydtSecond ,0, -g]  
    
    return[dxdtFirst,dydtFirst,dxdtSecond,dydtSecond, dxdtThird,dydtThird]


z = odeint( func=model1, y0=z0, t=t )
#z2 = odeint( func=model2, y0=z0, t=t )
#z3 = odeint( func=model3, y0=z0, t=t )


plt.plot(z[:, 0], z[:, 1])
#plt.plot(z2[0], z2[1])
#plt.plot(z3[0], z3[1])

#plt.plot(x1,y1)
#plt.plot(x2,y2)
#plt.plot(x3,y3)
plt.show()

# %% [markdown]
# # Wie Tornow es gegeben hat mit 4 Dif gl erster Ordnung

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint


#Anfangsbedienungen

# Vektor - Anfangsort

C = [4,3]

# Anfangsbedienung - Geschwindigkeit  x = 0, y = 1
z0 = [0, 1]   


t = np.linspace(0,10)
g = 9.81

C1 = C[0]
C2 = C[1]

def model1(z,t):
    x = z[0]
    y = z[1]
    y1 = C1 * t + x
    y2 = C1
    return[y1,y2]

def model2(z,t):    
    y1 = C1
    y2 = 0
    return[y1,y2]

def model3(z,t):
    y = z[1]
    y3 = -1/2 * g * t**2 + C2 + y
    y4 = -g*t + C2 
    return[y3,y4]

def model4(z,t):
    y3 = -g*t + C2 
    y4 = -g
    return[y3,y4]

z1 = odeint( func=model1, y0=z0, t=t )
z2 = odeint( func=model2, y0=z0, t=t )
z3 = odeint( func=model3, y0=z0, t=t )
z4 = odeint( func=model4, y0=z0, t=t )

x1=z1[:,0]
y1=z1[:,1]
x2=z2[:,0]
y2=z2[:,1]
x3=z3[:,0]
y3=z3[:,1]


plt.plot(z1[0], z1[1], z2[0], z2[1], z3[0], z3[1],z4[0], z4[1])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint


#Anfangsbedienungen

# Vektor - Anfangsort

C = [4,3]

# Anfangsbedienung - Geschwindigkeit  x = 0, y = 1
z0 = [0, 1] 


t = np.linspace(0,10)
g = 9.81

C1 = C[0]
C2 = C[1]

x1 = z[0]
x2 = C1
x3 = 0

def model1(z,t):
    x = z[0]
    y = z[1]
    dxdtFirst = C1 * t + x
    dydtFirst = -1/2 * F * t**2 + C2 * t + y
    return[dxdtFirst,dydtFirst]

def model2(z,t):    
    dxdtSecond = C1 
    dydtSecond = -g*t + C2  
    return[dxdtSecond,dydtSecond]

def model3(z,t):
    dxdtThird = 0
    dydtThird = -g
    return[dxdtThird,dydtThird]



z1 = odeint( func=model1, y0=z0, t=t )
z2 = odeint( func=model2, y0=z0, t=t )
z3 = odeint( func=model3, y0=z0, t=t )


#plt.plot(z1[0], z1[1], z2[0], z2[1], z3[0], z3[1])

plt.plot(t,z1[:,0])
#plt.plot(t,z1[:,1])
plt.plot(t,z2[:,0])
#plt.plot(t,z2[:,1])
plt.plot(t,z3[:,0])
#plt.plot(t,z3[:,1])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint


#Anfangsbedienungen

# Vektor - Anfangsort

C = [2,10]

# Anfangsbedienung - Geschwindigkeit  x = 0, y = 1
#z0 = np.zeros(2)
z0 = [0,0]
#C1 = z0[2] = 4
#C2 = z0[3] = 10


t = np.linspace(0,10)
g = 9.81



C1 = C[0]
C2 = C[1]


def model1(z,t):
    x = z[0]
    y = z[1]
    dxdtFirst = C1 * t + x
    dydtFirst = -1/2 * F * t**2 + C2 * t + y
    return[dxdtFirst,dydtFirst]

def model2(z,t):    
    dxdtSecond = C1 
    dydtSecond = -g*t + C2  
    return[dxdtSecond,dydtSecond]

def model3(z,t):
    dxdtThird = 0
    dydtThird = -g
    return[dxdtThird,dydtThird]

z1 = odeint( func=model3, y0=z0, t=t )
z2 = odeint( func=model2, y0=z0, t=t )
z3 = odeint( func=model1, y0=z0, t=t )

x1=z1[:,0]
y1=z1[:,1]
x2=z2[:,0]
y2=z2[:,1]
x3=z3[:,0]
y3=z3[:,1]


plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint


#Anfangsbedienungen

# Vektor - Anfangsort
z0 = [0,0]

# Anfangsbedienung - Geschwindigkeit
C = [2,10]

C1 = C[0]
C2 = C[1]

#Die Zeit
t = np.linspace(0,10)

#Gravitationskraft = Masse * g
g = 9.81
m = 10
F = g*m


def model1(z,t):
    x = z[0]
    y = z[1]
    dxdtFirst = C1 * t + x
    dydtFirst = -1/2 * F * t**2 + C2 * t + y
    return[dxdtFirst,dydtFirst]

def model2(z,t):    
    dxdtSecond = C1 
    dydtSecond = -F*t + C2  
    return[dxdtSecond,dydtSecond]

def model3(z,t):
    dxdtThird = 0
    dydtThird = -F
    return[dxdtThird,dydtThird]

z1 = odeint( func=model3, y0=z0, t=t )
z2 = odeint( func=model2, y0=z0, t=t )
z3 = odeint( func=model1, y0=z0, t=t )

x1=z1[:,0]
y1=z1[:,1]
x2=z2[:,0]
y2=z2[:,1]
x3=z3[:,0]
y3=z3[:,1]


#plt.plot(t,z1[:,0])
#plt.plot(t,z1[:,1])
#plt.plot(t,z2[:,0])
#plt.plot(t,z2[:,1])
#plt.plot(t,z3[:,0])
#plt.plot(t,z3[:,1])
plt.plot(t,z1)
plt.plot(t,z2)
plt.plot(t,z3)
plt.show()

# %% [markdown]
# das habe ich hier gefunden: https://ipython-books.github.io/123-simulating-an-ordinary-differential-equation-with-scipy/

# %%
import numpy as np
import scipy.integrate as spi
import matplotlib.pyplot as plt
# %matplotlib inline

m = 1.  # particle's mass
k = 1.  # drag coefficient
g = 9.81  # gravity acceleration

# The initial position is (0, 0).
v0 = np.zeros(4)
# The initial speed vector is oriented
# to the top right.
v0[2] = 4.
v0[3] = 10.

def f(v, t0, k):
    # v has four components: v=[u, u'].
    u, udot = v[:2], v[2:]
    # We compute the second derivative u'' of u.
    udotdot = -k / m * udot
    udotdot[1] -= g
    # We return v'=[u', u''].
    return np.r_[udot, udotdot]

fig, ax = plt.subplots(1, 1, figsize=(8, 4))

# We want to evaluate the system on 30 linearly
# spaced times between t=0 and t=3.
t = np.linspace(0., 8., 30)

# We simulate the system for different values of k.
for k in np.linspace(0., 1., 5):
    # We simulate the system and evaluate $v$ on the
    # given times.
    v = spi.odeint(f, v0, t, args=(k,))
    # We plot the particle's trajectory.
    ax.plot(v[:, 0], v[:, 1], 'o-', mew=1, ms=8,
            mec='w', label=f'k={k:.1f}')
ax.legend()
ax.set_xlim(0, 12)
ax.set_ylim(0, 6)
# Out:
# (0, 6)
